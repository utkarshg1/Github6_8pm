# %% [markdown]
# # Install yfinance

# %%
# %pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Restart and run all cells

# %%
import yfinance as yf
ticker = 'SBIN.NS'
share_df = yf.download(tickers=ticker, period='3y', interval='1mo')
share_df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-12-01  245.000000  279.899994  244.100006  274.950012  263.135040
# 2021-01-01  274.899994  310.899994  269.500000  282.100006  269.977783
# 2021-02-01  285.100006  427.700012  282.750000  390.149994  373.384735
# 2021-03-01  395.100006  408.899994  345.200012  364.299988  348.645538
# 2021-04-01  367.700012  371.899994  321.299988  353.500000  338.309631
#
#                 Volume
# Date
# 2020-12-01   985080328
# 2021-01-01   777947672
# 2021-02-01  1532347646
# 2021-03-01   849338663
# 2021-04-01   929066645

# %%
share_df.index
# Out:
# DatetimeIndex(['2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01',
#                '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01',
#                '2021-08-01', '2021-09-01', '2021-10-01', '2021-11-01',
#                '2021-12-01', '2022-01-01', '2022-02-01', '2022-03-01',
#                '2022-04-01', '2022-05-01', '2022-06-01', '2022-07-01',
#                '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01',
#                '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01',
#                '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01',
#                '2023-08-01', '2023-09-01', '2023-10-01', '2023-11-01'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
type(share_df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df_close = share_df[['Close']]

# %%
df_close
# Out:
#                  Close
# Date
# 2020-12-01  274.950012
# 2021-01-01  282.100006
# 2021-02-01  390.149994
# 2021-03-01  364.299988
# 2021-04-01  353.500000
# 2021-05-01  424.350006
# 2021-06-01  419.200012
# 2021-07-01  431.799988
# 2021-08-01  426.049988
# 2021-09-01  453.000000
# 2021-10-01  502.149994
# 2021-11-01  460.549988
# 2021-12-01  460.450012
# 2022-01-01  538.299988
# 2022-02-01  483.200012
# 2022-03-01  493.549988
# 2022-04-01  496.299988
# 2022-05-01  468.100006
# 2022-06-01  465.899994
# 2022-07-01  528.349976
# 2022-08-01  531.250000
# 2022-09-01  530.599976
# 2022-10-01  573.799988
# 2022-11-01  602.450012
# 2022-12-01  613.700012
# 2023-01-01  553.500000
# 2023-02-01  522.799988
# 2023-03-01  523.750000
# 2023-04-01  578.299988
# 2023-05-01  579.849976
# 2023-06-01  572.849976
# 2023-07-01  620.200012
# 2023-08-01  561.349976
# 2023-09-01  598.549988
# 2023-10-01  565.549988
# 2023-11-01  558.950012
